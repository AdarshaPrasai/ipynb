# %% [markdown]
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
import pandas as pd

# Load the dataset provided by the user
data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

# Display the first 10 rows of the dataset
first_10_rows = data.head(10)
print("First 10 rows of the dataset:")
print(first_10_rows)

# Identify the number of rows and columns in the dataset
num_rows, num_columns = data.shape
print(f"\nNumber of rows: {num_rows}")
print(f"Number of columns: {num_columns}")

# List all the columns and their data types
columns_info = data.dtypes
print("\nColumns and their data types:")
print(columns_info)
# Out:
# First 10 rows of the dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.**bold text** **bold text**

# %%
mean=data["score"].mean()
median=data["score"].median()
sd=data["score"].std()
print(f" Mean: {mean}\n Median: {median}\n Standard Deviation: {sd}\n")
high_score=data.loc[data["score"].idxmax(),"Country name"]
low_score=data.loc[data["score"].idxmin(),"Country name"]
print("Country with the highest happiness score: ",high_score)
print("Country with the lowest happiness score: ",low_score)
# Out:
#  Mean: 5.52758041958042
#  Median: 5.785
#  Standard Deviation: 1.1707165099442995
#
# Country with the highest happiness score:  Finland
# Country with the lowest happiness score:  Afghanistan

# %% [markdown]
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# Check for missing values in the dataset
missing_values = data.isnull().sum()

print("\nMissing values in each column:")
print(missing_values)

# Check if the dataset has any missing values overall
has_missing = data.isnull().values.any()
if has_missing:
    print("\nThe dataset contains missing values.")
else:
    print("\nThe dataset does not contain any missing values.")
# Out:
# Missing values in each column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64
#
# The dataset contains missing values.

# %% [markdown]
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

# 1. Filter the dataset to include only countries with a Score greater than 7.5
filtered_data = data[data['score'] > 7.5]

# 2. Sort the filtered dataset by GDP per Capita in descending order
sorted_data = filtered_data.sort_values(by='Log GDP per capita', ascending=False)

# Display the top 10 rows of the sorted dataset
top_10_countries = sorted_data.head(10)
print("Top 10 countries with a Score > 7.5 sorted by GDP per Capita:")
print(top_10_countries[['Country name', 'score', 'Log GDP per capita']])
# Out:
# Top 10 countries with a Score > 7.5 sorted by GDP per Capita:
#   Country name  score  Log GDP per capita
# 1      Denmark  7.583               1.908
# 2      Iceland  7.525               1.881
# 0      Finland  7.741               1.844

# %% [markdown]
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
import pandas as pd

# Load the dataset from the provided file path
data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

# Function to categorize the countries based on their Score
def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'

# Apply the function to the 'Score' column and create a new 'Happiness Category' column
data['Happiness Category'] = data['score'].apply(categorize_happiness)
data.head()

# Display the updated dataframe with the new column
print(data.head())
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 3                    0.724                         0.838       0.221
# 4                    0.740                         0.641       0.153
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# 0                      0.546                2.082               High
# ...

# %% [markdown]
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
# • Plot a histogram for the Score column to show its distribution and also interpret.
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

plt.plot(data.tail(10)['Country name'], data.tail(10)['score'], color="blue", marker='o', label='Happiness Score')

plt.xticks(rotation=90)
plt.title('Top 10 Unhappiest Countries by Score')
plt.xlabel('Country Name')
plt.ylabel('Score')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

happiest = data.sort_values(by="score", ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=happiest, x="Country name", y="score", color='skyblue', label='Happiness Score')

plt.title("Top 10 Happiest Countries by Score")
plt.xlabel("Country Name")
plt.ylabel("Happiness Score")
plt.xticks(rotation=45)
plt.legend(title='Legend')

plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

sns.histplot(data['score'], bins=20, kde=True, color='skyblue', label='Happiness Score')

plt.title('Distribution of Happiness Scores')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Legend')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

plt.figure(figsize=(12, 6))
sns.scatterplot(data, x="Log GDP per capita", y="score", label='GDP vs Score')

plt.title("GDP per Capita vs Score")
plt.xlabel("GDP per Capita")
plt.ylabel("Score")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# Use the list from step- 1 to filtered the dataset {i.e. filtered out matching dataset from list.

# %%
import pandas as pd

# Step 1: Define the list of South Asian countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# Step 2: Load the dataset
data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

# Step 3: Filter the dataframe based on the South Asian countries list
filtered_df = data[data['Country name'].isin(south_asian_countries)]

# Step 4: Save the filtered dataframe to a new CSV file
filtered_df.to_csv('/content/drive/MyDrive/Assesment/south_asian_countries_filtered.csv', index=False)

# Display the filtered dataframe (optional)
print(filtered_df)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

# Define the list of South Asian countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# Filter the dataframe for South Asian countries
south_asian_df = data[data['Country name'].isin(south_asian_countries)]

# Calculate the Composite Score
south_asian_df['Composite Score'] = (0.40 * south_asian_df['Log GDP per capita'] +
                                      0.30 * south_asian_df['Social support'] +
                                      0.30 * south_asian_df['Healthy life expectancy'])

# Show the updated dataframe with Composite Score
print(south_asian_df[['Country name', 'Composite Score']])
# Out:
#     Country name  Composite Score
# 92         Nepal           0.8159
# 107     Pakistan           0.7039
# 125        India           0.7874
# 127    Sri Lanka           1.0739
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238
# <ipython-input-44-c9701f83ca6a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asian_df['Composite Score'] = (0.40 * south_asian_df['Log GDP per capita'] +

# %% [markdown]
# Rank the Countries Based on Composite Score

# %%
# Rank the countries based on Composite Score in descending order
south_asian_df = south_asian_df.sort_values(by='Composite Score', ascending=False)

# Show the top-ranked countries based on Composite Score
print(south_asian_df[['Country name', 'Composite Score']].head(10))
# Out:
#     Country name  Composite Score
# 127    Sri Lanka           1.0739
# 92         Nepal           0.8159
# 125        India           0.7874
# 107     Pakistan           0.7039
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238

# %% [markdown]
# Visualize the Top 5 Countries Using a Horizontal Bar Chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the top 5 countries using a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=south_asian_df.head(5), x='Composite Score', y='Country name')
plt.title('Top 5 South Asian Countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country Name')
plt.show()

# %% [markdown]
# Compare Composite Score with Original Score

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
south_asian_df = data[data['Country name'].isin(south_asian_countries)]

# Calculate the Composite Score
south_asian_df['Composite Score'] = (0.40 * south_asian_df['Log GDP per capita'] +
                                     0.30 * south_asian_df['Social support'] +
                                     0.30 * south_asian_df['Healthy life expectancy'])

# Sort and select top 5 South Asian countries based on Composite Score
top5 = south_asian_df.sort_values(by='Composite Score', ascending=False).head(5)

# Plot Composite Score
plt.figure(figsize=(10, 6))
sns.barplot(data=top5, x='Composite Score', y='Country name', color='skyblue')
plt.title('Top 5 South Asian Countries - Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country Name')
plt.show()

# Plot Original Score
plt.figure(figsize=(10, 6))
sns.barplot(data=top5, x='score', y='Country name', color='skyblue')
plt.title('Top 5 South Asian Countries - Original Score')
plt.xlabel('Original Score')
plt.ylabel('Country Name')
plt.show()
# Out:
# <ipython-input-47-fa96a5a7f108>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asian_df['Composite Score'] = (0.40 * south_asian_df['Log GDP per capita'] +

# %% [markdown]
# #4 no answer:

# %% [markdown]
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.

# %%
Q1 = south_asian_df['score'].quantile(0.25)
Q3 = south_asian_df['score'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = south_asian_df[(south_asian_df['score'] < lower_bound) | (south_asian_df['score'] > upper_bound)]
print("Outliers based on Score:")
print(outliers)
# Out:
# Outliers based on Score:
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual  Composite Score
# 142                      0.088                0.672           0.3238

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
print(south_asian_df)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
plt.scatter(south_asian_df['Log GDP per capita'], south_asian_df['score'], color='blue', label='Non-Outliers')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], color='red', label='Outliers')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter plot of GDP per Capita vs Score with Outliers')
plt.legend()
plt.show()

# %%
print(south_asian_df)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Calculate Pearson correlation between 'Freedom to Make Life Choices' and 'Score'
freedom_correlation = south_asian_df['Freedom to make life choices'].corr(south_asian_df['score'])
generosity_correlation = south_asian_df['Generosity'].corr(south_asian_df['score'])

print(f"Pearson Correlation between Freedom to Make Life Choices and Score: {freedom_correlation}")
print(f"Pearson Correlation between Generosity and Score: {generosity_correlation}")

# Create scatter plots with trendlines
plt.figure(figsize=(12, 6))

# Scatter plot for Freedom to Make Life Choices vs Score
plt.subplot(1, 2, 1)
sns.regplot(x='Freedom to make life choices', y='score', data=south_asian_df, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('score')

# Scatter plot for Generosity vs Score
plt.subplot(1, 2, 2)
sns.regplot(x='Generosity', y='score', data=south_asian_df, scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
plt.title('Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('score')

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Pearson Correlation between Freedom to Make Life Choices and Score: 0.8005185224163315
# Pearson Correlation between Generosity and Score: 0.874512371253192

# %%
print(south_asian_df)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score for each South Asian country.
south_asian_df['GDP-Score Gap'] = south_asian_df['Log GDP per capita'] - south_asian_df['score']
south_asian_df.head(6)
# Out:
# <ipython-input-64-71182cdedc27>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asian_df['GDP-Score Gap'] = south_asian_df['Log GDP per capita'] - south_asian_df['score']
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
# Rank the South Asian countries by this gap in both ascending and descending order.

ascending_order = south_asian_df.sort_values(by='GDP-Score Gap')
descending_order = south_asian_df.sort_values(by='GDP-Score Gap', ascending=False)
print("Ascending order: \n", ascending_order)
print("Descending order: \n", descending_order)
# Out:
# Ascending order:
#      Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 127    Sri Lanka  3.898               1.361           1.179
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
# 127                    0.586                         0.583       0.144
# 142                    0.242                         0.000       0.091
#
# ...

# %%
# Step 3: Highlight the top 3 countries with the largest positive and negative gaps
top3_positive = descending_order.head(3)
top3_negative = ascending_order.head(3)

# Create a bar chart for the top 3 positive and negative GDP-Score Gaps
plt.figure(figsize=(10, 6))

# Plot for positive GDP-Score Gap
sns.barplot(x='GDP-Score Gap', y='Country name', data=top3_positive, color='lightgreen', label='Positive Gap')

# Plot for negative GDP-Score Gap
sns.barplot(x='GDP-Score Gap', y='Country name', data=top3_negative, color='red', label='Negative Gap')

plt.title('Top 3 Positive and Negative GDP-Score Gaps')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country Name')

# Add legend
plt.legend()

# Show the plot
plt.show()

# Step 4: Analyze the reasons behind these gaps
print(f"Top 3 countries with the largest positive GDP-Score Gap:\n{top3_positive[['Country name', 'GDP-Score Gap']]}")
print(f"Top 3 countries with the largest negative GDP-Score Gap:\n{top3_negative[['Country name', 'GDP-Score Gap']]}")
# Out:
# Top 3 countries with the largest positive GDP-Score Gap:
#     Country name  GDP-Score Gap
# 142  Afghanistan         -1.093
# 127    Sri Lanka         -2.537
# 128   Bangladesh         -2.764
# Top 3 countries with the largest negative GDP-Score Gap:
#     Country name  GDP-Score Gap
# 92         Nepal         -4.193
# 107     Pakistan         -3.588
# 125        India         -2.888

# %% [markdown]
# Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/Assesment/Assignment 1 WHR 2024 5CS037.csv')

# List of Middle Eastern countries
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan",
                         "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar",
                         "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# Filter the dataframe for Middle Eastern countries
middle_east_df = data[data['Country name'].isin(middle_east_countries)]

# Display the new dataframe containing only Middle Eastern countries
print(middle_east_df)
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
#statistics for South Asia
south_asia_mean = south_asian_df['score'].mean()
south_asia_median = south_asian_df['score'].median()
south_asia_std = south_asian_df['score'].std()

#statistics for Middle East
middle_east_mean = middle_east_df['score'].mean()
middle_east_median = middle_east_df['score'].median()
middle_east_std = middle_east_df['score'].std()

# Display results for both regions
print("South Asia Statistics:")
print(f"Mean: {south_asia_mean}, Median: {south_asia_median}, Standard Deviation: {south_asia_std}")
print("\nMiddle East Statistics:")
print(f"Mean: {middle_east_mean}, Median: {middle_east_median}, Standard Deviation: {middle_east_std}")

# Compare mean scores
if south_asia_mean > middle_east_mean:
    print("\nSouth Asia has a higher average happiness score.")
else:
    print("\nMiddle East has a higher average happiness score.")
# Out:
# South Asia Statistics:
# Mean: 3.895666666666667, Median: 3.976, Standard Deviation: 1.1770690152521504
#
# Middle East Statistics:
# Mean: 5.412100000000001, Median: 5.5625, Standard Deviation: 1.5662011684327144
#
# Middle East has a higher average happiness score.

# %% [markdown]
# • Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.

# %%
# Identify top 3 and bottom 3 countries by score for South Asia
top3_sa = south_asian_df.nlargest(3, 'score')[['Country name', 'score']]
bottom3_sa = south_asian_df.nsmallest(3, 'score')[['Country name', 'score']]
print("Top 3 countries in South Asia: \n", top3_sa)
print("Bottom 3 countries in South Asia: \n", bottom3_sa)

# Identify top 3 and bottom 3 countries by score for Middle East
top3_me = middle_east_df.nlargest(3, 'score')[['Country name', 'score']]
bottom3_me = middle_east_df.nsmallest(3, 'score')[['Country name', 'score']]
print("Top 3 countries in Middle East: \n", top3_me)
print("Bottom 3 countries in Middle East: \n", bottom3_me)

# Combine top 3 and bottom 3 into single DataFrames for each region
sa_combined = pd.concat([top3_sa, bottom3_sa]).reset_index(drop=True)
me_combined = pd.concat([top3_me, bottom3_me]).reset_index(drop=True)

# Plot bar chart for South Asia
plt.figure(figsize=(12, 6))
sns.barplot(data=sa_combined, x='score', y='Country name')
plt.title('Top 3 and Bottom 3 South Asian Countries by Score')
plt.xlabel('Score')
plt.ylabel('Country Name')
plt.show()

# Plot bar chart for Middle East
plt.figure(figsize=(12, 6))
sns.barplot(data=me_combined, x='score', y='Country name')
plt.title('Top 3 and Bottom 3 Middle Eastern Countries by Score')
plt.xlabel('Score')
plt.ylabel('Country Name')
plt.show()
# Out:
# Top 3 countries in South Asia:
#      Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054
# Bottom 3 countries in South Asia:
#      Country name  score
# 142  Afghanistan  1.721
# 128   Bangladesh  3.886
# 127    Sri Lanka  3.898
# Top 3 countries in Middle East:
#              Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733
# Bottom 3 countries in Middle East:
#      Country name  score
# 141      Lebanon  2.707
# 132        Yemen  3.561
# 124       Jordan  4.186

# %% [markdown]
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
# • Which metrics show the largest disparity between the two regions?

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate mean values of the key metrics for both regions
key_metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
sa_means = south_asian_df[key_metrics].mean()
me_means = middle_east_df[key_metrics].mean()

# Combine into a single DataFrame for plotting
comparison_df = pd.DataFrame({
    'Metric': key_metrics,
    'South Asia': sa_means.values,
    'Middle East': me_means.values
}).melt(id_vars='Metric', var_name='Region', value_name='Mean Value')

# Plot grouped bar chart
plt.figure(figsize=(12, 6))
sns.barplot(data=comparison_df, x='Metric', y='Mean Value', hue='Region')
plt.title('Comparison of Key Metrics Between South Asia and Middle East')
plt.xlabel('Metric')
plt.ylabel('Mean Value')
plt.legend(title='Region')
plt.show()

# Calculate the disparity between the two regions for each metric
disparities = np.abs(sa_means - me_means)

# Identify the metric with the largest disparity
largest_disparity_metric = disparities.idxmax()
largest_disparity_value = disparities.max()

print(f"The metric with the largest disparity is '{largest_disparity_metric}' with a difference of {largest_disparity_value:.2f}.")
# Out:
# The metric with the largest disparity is 'Social support' with a difference of 0.54.

# %% [markdown]
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
# Calculate the range (max - min) for Score in both regions
range_sa = south_asian_df['score'].max() - south_asian_df['score'].min()
range_me = middle_east_df['score'].max() - middle_east_df['score'].min()

# Calculate the coefficient of variation (CV) for Score in both regions
cv_sa = south_asian_df['score'].std() / south_asian_df['score'].mean()
cv_me = middle_east_df['score'].std() / middle_east_df['score'].mean()

# Print results
print("South Asia:")
print(f"Range: {range_sa:.2f}")
print(f"Coefficient of Variation (CV): {cv_sa:.2f}")

print("\nMiddle East:")
print(f"Range: {range_me:.2f}")
print(f"Coefficient of Variation (CV): {cv_me:.2f}")

# Determine which region has greater variability
if cv_sa > cv_me:
    print("\nSouth Asia has greater variability in happiness.")
else:
    print("\nMiddle East has greater variability in happiness.")
# Out:
# South Asia:
# Range: 3.44
# Coefficient of Variation (CV): 0.30
#
# Middle East:
# Range: 4.63
# Coefficient of Variation (CV): 0.29
#
# South Asia has greater variability in happiness.

# %% [markdown]
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.

# %% [markdown]
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.

# %%
metrics = ['Freedom to make life choices', 'Generosity', 'score']

south_asia_corr = south_asian_df[metrics].corr()['score']
print("South Asia Correlations:")
print(south_asia_corr)

middle_east_corr = middle_east_df[metrics].corr()['score']
print("\nMiddle East Correlations:")
print(middle_east_corr)

plt.suptitle('Correlation of Metrics with Score (South Asia)', fontsize=16)

plt.subplot(1, 2, 1)
sns.scatterplot(data=south_asian_df, x='Freedom to make life choices', y='score', color='blue', label='South Asia')
plt.title('Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

plt.subplot(1, 2, 2)
sns.scatterplot(data=south_asian_df, x='Generosity', y='score', color='green', label='South Asia')
plt.title('Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

plt.suptitle('Correlation of Metrics with Score (Middle East)', fontsize=16)

plt.subplot(1, 2, 1)
sns.scatterplot(data=middle_east_df, x='Freedom to make life choices', y='score', color='blue', label='Middle East')
plt.title('Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

plt.subplot(1, 2, 2)
sns.scatterplot(data=middle_east_df, x='Generosity', y='score', color='green', label='Middle East')
plt.title('Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()
# Out:
# South Asia Correlations:
# Freedom to make life choices    0.800519
# Generosity                      0.874512
# score                           1.000000
# Name: score, dtype: float64
#
# Middle East Correlations:
# Freedom to make life choices    0.863220
# Generosity                      0.627524
# score                           1.000000
# Name: score, dtype: float64

# %% [markdown]
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Function to identify outliers using the 1.5 × IQR rule
def find_outliers(data, column):
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return data[(data[column] < lower_bound) | (data[column] > upper_bound)]

# Identify outliers for Score and GDP per Capita in both regions
south_asian_outliers = pd.concat([
    find_outliers(south_asian_df, 'score'),
    find_outliers(south_asian_df, 'Log GDP per capita')
]).drop_duplicates()

middle_east_outliers = pd.concat([
    find_outliers(middle_east_df, 'score'),
    find_outliers(middle_east_df, 'Log GDP per capita')
]).drop_duplicates()

# Scatter plots for South Asia
plt.figure(figsize=(10, 6))
sns.scatterplot(data=south_asian_df, x='Log GDP per capita', y='score', color='blue', label='South Asia')
sns.scatterplot(data=south_asian_outliers, x='Log GDP per capita', y='score', color='red', label='Outliers')
plt.title("South Asia: Outliers in Score and GDP per Capita")
plt.xlabel("GDP per Capita")
plt.ylabel("Score")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Scatter plots for Middle East
plt.figure(figsize=(10, 6))
sns.scatterplot(data=middle_east_df, x='Log GDP per capita', y='score', color='green', label='Middle East')
sns.scatterplot(data=middle_east_outliers, x='Log GDP per capita', y='score', color='red', label='Outliers')
plt.title("Middle East: Outliers in Score and GDP per Capita")
plt.xlabel("GDP per Capita")
plt.ylabel("Score")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Print outliers
print("South Asia Outliers:")
print(south_asian_outliers[['Country name', 'score', 'Log GDP per capita']])

print("\nMiddle East Outliers:")
print(middle_east_outliers[['Country name', 'score', 'Log GDP per capita']])
# Out:
# South Asia Outliers:
#     Country name  score  Log GDP per capita
# 142  Afghanistan  1.721               0.628
#
# Middle East Outliers:
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita]
# Index: []

# %% [markdown]
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combine South Asia and Middle East data into one DataFrame
combined_df = pd.concat([
    south_asian_df.assign(Region='South Asia'),
    middle_east_df.assign(Region='Middle East')
])

# Create boxplots for the Score
plt.figure(figsize=(10, 6))
sns.boxplot(data=combined_df, x='Region', y='score', palette='coolwarm')
plt.title('Comparison of Score Distribution: South Asia vs Middle East')
plt.xlabel('Region')
plt.ylabel('Score')
plt.show()
# Out:
# <ipython-input-62-577cd67645fb>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=combined_df, x='Region', y='score', palette='coolwarm')
